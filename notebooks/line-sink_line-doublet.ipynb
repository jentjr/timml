# %% [markdown]
# # Consider a cylindrical impermeable object

# %%
from timml import *
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# \begin{equation*}
# \Omega=-Q_{x0}(z+R^2/z)+C
# \end{equation*}

# %%
y, x = (1*np.sin(np.linspace(-np.pi, np.pi, 30)), 1*np.cos(np.linspace(-np.pi, np.pi, 30))) 
xy = list(zip(x, y))

# %%
CircAreaSink?
# Out:
# Init signature: CircAreaSink(model, xc=0, yc=0, R=1, N=0.001, layer=0, name='CircAreasink', label=None)
# Docstring:      <no docstring>
# File:           ~/anaconda3/envs/timml/lib/python3.6/site-packages/timml/circareasink.py
# Type:           type

# %%
ml = ModelMaq(kaq=[100], z=[10, 0])
uf = Uflow(ml, slope=0.01, angle=0)
ld = ImpLineDoubletString(ml, xy=xy)
ml.solve()
# Out:
# Number of elements, Number of equations: 2 , 29
# ..
# solution complete

# %%
ml.contour(win=[-2, 2, -2, 2], ngr=20, levels=30, labels=True, figsize=(10, 10))

# %%
circ = CircAreaSink(ml, xc=0, yc=0, R=4, N=0.01)

# %%
ml.solve()
# Out:
# Number of elements, Number of equations: 3 , 29
# ...
# solution complete

# %%
ml.contour(win=[-2, 2, -2, 2], ngr=20, levels=30, labels=True, figsize=(10, 10))

# %%
ml = ModelMaq(kaq=[100], z=[10, 0])
uf = Uflow(ml, slope=0.01, angle=0)
ld = LeakyLineDoubletString(ml, xy=xy, res=1, order=0)
ml.solve()
# Out:
# Number of elements, Number of equations: 2 , 29
# ..
# solution complete

# %%
ml.contour(win=[-2, 2, -2, 2], ngr=20, levels=30, labels=True, figsize=(10, 10))

# %%
circ = CircAreaSink(ml, xc=0, yc=0, R=4, N=0.01)

# %%
ml.solve()
# Out:
# Number of elements, Number of equations: 3 , 29
# ...
# solution complete

# %%
ml.contour(win=[-2, 2, -2, 2], ngr=20, levels=30, labels=True, figsize=(10, 10))

# %%
ml = ModelMaq(kaq=[1], z=[10, 0])
uf = Uflow(ml, slope=0.01, angle=0)
ld = PolygonInhomMaq(ml, xy=xy, c=1, order=3)
ml.solve()
# Out:
# Number of elements, Number of equations: 60 , 233
# ............................................................
# solution complete

# %%
ml.contour(win=[-2, 2, -2, 2], ngr=20, levels=30, labels=True, figsize=(10, 10))

# %%
circ = CircAreaSink(ml, xc=0, yc=0, R=4, N=0.01)

# %%
ml.solve()
# Out:
# Number of elements, Number of equations: 61 , 233
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-5224deb6582a> in <module>
# ----> 1 ml.solve()
#
# ~/anaconda3/envs/timml/lib/python3.6/site-packages/timml/model.py in solve(self, printmat, sendback, silent)
#     291             if e.nunknowns > 0:
#     292                 mat[ieq:ieq + e.nunknowns, :], rhs[ieq:ieq + e.nunknowns] = \
# --> 293                 e.equation()
#     294                 ieq += e.nunknowns
#     295             if silent is False:
#
# ~/anaconda3/envs/timml/lib/python3.6/site-packages/timml/equation.py in equation(self)
#     278                                           self.xcin[icp+1], self.ycin[icp+1], self.layers, aq=self.aqin)
#     279                     fluxout = self.intflux(e.disveclayers, self.xcout[icp], self.ycout[icp], \
# ...

# %%
ml.contour(win=[-2, 2, -2, 2], ngr=20, levels=30, labels=True, figsize=(10, 10))
