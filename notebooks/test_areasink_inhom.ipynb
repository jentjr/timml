# %%
from timml import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ml = ModelMaq()
#c = Constant(ml, xr=2, yr=2, hr=1)
circ = CircAreaSink(ml, xc=0, yc=0, R=1, N=1)
ml.solve()
ml.contour(win=[-2, 2, -2, 2], figsize=(10, 10), decimals=2)
print(ml.headalongline(x=[-2, -1, 0, 1, 2], y=[0, 0, 0, 0, 0]))
# Out:
# [[-0.34657359  0.          0.25        0.         -0.34657359]]

# %%
ml = ModelMaq()
#c = Constant(ml, xr=2, yr=2, hr=1)
# inhomogeneity specified with sampe aquifer properties
inhom = PolygonInhomMaq(ml, xy=[(-1, -1), (1, -1), (1, 1), (-1, 1)])
circ = CircAreaSink(ml, xc=0, yc=0, R=1, N=1)
ml.solve()
ml.contour(win=[-2, 2, -2, 2], figsize=(10, 10), decimals=2)
print(ml.headalongline(x=[-2, -1, 0, 1, 2], y=[0, 0, 0, 0, 0]))
# Out:
# Number of elements, Number of equations: 10 , 33
# ..........
# solution complete
# [[-0.34661359 -0.00064907  0.24970676 -0.00064907 -0.34661359]]

# %%
ml = ModelMaq()
#c = Constant(ml, xr=2, yr=2, hr=1)
# inhomogeneity specified with sampe aquifer properties
inhom = PolygonInhomMaq(ml, xy=[(-1, -1), (1, -1), (1, 1), (-1, 1)])
circ = CircAreaSink(ml, xc=0, yc=0, R=1.5, N=1)
ml.solve()
ml.contour(win=[-2, 2, -2, 2], figsize=(10, 10), decimals=2)
print(ml.headalongline(x=[-2, -1, 0, 1, 2], y=[0, 0, 0, 0, 0]))
# Out:
# Number of elements, Number of equations: 10 , 33
# ..
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-2a48346d2b14> in <module>
#       4 inhom = PolygonInhomMaq(ml, xy=[(-1, -1), (1, -1), (1, 1), (-1, 1)])
#       5 circ = CircAreaSink(ml, xc=0, yc=0, R=1.5, N=1)
# ----> 6 ml.solve()
#       7 ml.contour(win=[-2, 2, -2, 2], figsize=(10, 10), decimals=2)
#       8 print(ml.headalongline(x=[-2, -1, 0, 1, 2], y=[0, 0, 0, 0, 0]))
#
# h:\internal\jrj\github\timml\timml\model.py in solve(self, printmat, sendback, silent)
#     307                 mat[ieq : ieq + e.nunknowns, :], rhs[
#     308                     ieq : ieq + e.nunknowns
# --> 309                 ] = e.equation()
#     310                 ieq += e.nunknowns
#     311             if silent is False:
#
# h:\internal\jrj\github\timml\timml\equation.py in equation(self)
# ...

# %%
ml = ModelMaq()
#c = Constant(ml, xr=2, yr=2, hr=1)
strip = StripAreaSink(ml, xleft=-0.5, xright=0.5, N=1)
ml.solve()
ml.contour(win=[-2, 2, -2, 2], figsize=(10, 10), decimals=2)
print(ml.headalongline(x=[-2, -1, 0, 1, 2], y=[0, 0, 0, 0, 0]))
# Out:
# [[-0.875 -0.375  0.    -0.375 -0.875]]

# %%
ml = ModelMaq()
#c = Constant(ml, xr=2, yr=2, hr=1)
inhom = PolygonInhomMaq(ml, xy=[(-1, -1), (1, -1), (1, 1), (-1, 1)])
strip = StripAreaSink(ml, xleft=-0.5, xright=0.5, N=1)
ml.solve()
ml.contour(win=[-2, 2, -2, 2], figsize=(10, 10), decimals=2)
print(ml.headalongline(x=[-2, -1, 0, 1, 2], y=[0, 0, 0, 0, 0]))
# Out:
# Number of elements, Number of equations: 10 , 33
# ..........
# solution complete
# [[-0.23351391 -0.02502768  0.20629724 -0.02502768 -0.23351391]]

# %%
ml = ModelMaq()
#c = Constant(ml, xr=2, yr=2, hr=1)
strip = StripAreaSink(ml, xleft=-1.5, xright=1.5, N=1)
ml.solve()
ml.contour(win=[-2, 2, -2, 2], figsize=(10, 10), decimals=2)
print(ml.headalongline(x=[-2, -1, 0, 1, 2], y=[0, 0, 0, 0, 0]))
# Out:
# [[-1.875 -0.5    0.    -0.5   -1.875]]

# %%
ml = ModelMaq()
#c = Constant(ml, xr=2, yr=2, hr=1)
inhom = PolygonInhomMaq(ml, xy=[(-1, -1), (1, -1), (1, 1), (-1, 1)])
strip = StripAreaSink(ml, xleft=-1.5, xright=1.5, N=1)
ml.solve()
ml.contour(win=[-2, 2, -2, 2], figsize=(10, 10), decimals=2)
print(ml.headalongline(x=[-2, -1, 0, 1, 2], y=[0, 0, 0, 0, 0]))
# Out:
# Number of elements, Number of equations: 10 , 33
# ..........
# solution complete
# [[-0.44836017 -0.01497958  0.23371673 -0.01497958 -0.44836017]]

# %%
ml = ModelMaq()
xy = [(-1, -1), (1, -1), (1, 1), (-1, 1)]
poly = PolyAreaSink(ml, xy=xy, N=1)
ml.solve()
ml.contour(win=[-2, 2, -2, 2], figsize=(10, 10), decimals=2)
print(ml.headalongline(x=[-2, -1, 0, 1, 2], y=[0, 0, 0, 0, 0]))
# Out:
# [[-0.0189707  -0.01019188 -0.00877881 -0.01019188 -0.0189707 ]]
